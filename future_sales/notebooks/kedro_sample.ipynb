# %%
df = context.catalog.load('prm_train')

# %%
df.dtypes
# Out:
# shop_id                 int64
# item_id                 int64
# item_category_id        int64
# item_name              object
# item_category_name     object
# shop_name              object
# item_cnt_day          float64
# item_price            float64
# date                   object
# date_block_num          int64
# dtype: object

# %%
catalog.list()

# %%
df
# Out:
#          shop_id  item_id  item_category_id  \
# 0             59    22154                37
# 1             25     2552                58
# 2             25     2552                58
# 3             25     2554                58
# 4             25     2555                56
# 5             25     2564                59
# 6             25     2565                56
# 7             25     2572                55
# 8             25     2572                55
# 9             25     2573                55
# 10            25     2574                55
# 11            25     2574                55
# 12            25     2574                55
# 13            25     2574                55
# 14            25     2574                55
# 15            25     2574                55
# 16            25     2574                55
# 17            25     2574                55
# 18            25     2574                55
# 19            25     2574                55
# ...

# %%
raw_test.columns
